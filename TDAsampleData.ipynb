# %%
from ripser import ripser
from persim import plot_diagrams
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D

# %%
x1 = np.array([1, 2.2, 1.5, 2.3, 5.8, 4.1, 6.7, 5.8, 4.9, 7.7, 6.5, 9.6, 9.3, 11.2, 3.4, 5.4, 8.4, 6.5, 1.1, 2.4, 3.2, 4.4, 7.7, 6.6,
             3.2, 2.9, 9.8, 8, 3, 2.2, 9.5,
               1.2, 2.3, 1.4, 2.5, 5.7, 4.4, 6.5, 5.6, 4.7, 7.8, 6.9, 9.7, 9.6, 11.4, 3.7, 5.6, 8.3, 6.2, 1.5, 2.6, 3.7, 4.9, 7.2, 6.5,
             3.1, 2.5, 9.6, 8.3, 3.5, 2.7, 9.1, 8])
y1 = np.array([1, 1.5, 2.2, 3.6, 4.7, 4.3, 7.6, 6.3, 3.7, 6.5, 7.7, 7.3, 10.3, 10.4, 4.2, 5.9, 8.7, 6.8, 0.7, 2.1, 2.7, 4.5, 8.4, 5.9,
             2.7, 2.4 ,9.4, 8, 3, 2.2, 9.7,
              1.2, 1.6, 2.7, 3.1, 4.1, 4.3, 7.5, 6.6, 3.8, 6.1, 7.3, 7.7, 10.8, 10.1, 4.3, 5.5, 8.2, 6.1, 0.5, 2.3, 2.1, 4.1, 8.9, 5.0,
             2.1, 2.8 ,9.6, 8.5, 3.7, 2.9, 9.1,8.5])

# %%
x2 = np.array([1, 2.2, 1.5, 2.3, 5.8, 4.1, 6.7, 5.8, 4.9, 7.7, 6.5, 9.6, 9.3, 11.2, 3.4, 5.4, 8.4, 6.5, 1.1, 2.4, 3.2, 4.4, 7.7, 6.6,
             3.2, 2.9, 9.8, 8, 3, 2.2, 9.5,
              1.2, 2.3, 1.4, 2.5, 5.7, 4.4, 6.5, 5.6, 4.7, 7.8, 6.9, 9.7, 9.6, 11.4, 3.7, 5.6, 8.3, 6.2, 1.5, 2.6, 3.7, 4.9, 7.2, 6.5,
             3.1, 2.5, 9.6, 8.3, 3.5, 2.7, 9.1, 8])
y2 = np.array([1, 4.3, 2.2, 4.7, 7.7, 7.3, 3, 8.7, 7.6, 2.4, 8.4, 5.9, 3.7, 10.4, 8, 2.7, 2.2, 2.1, 0.7, 6.8, 5.9, 1.5, 3.6, 2.7,
             6.5, 4.2, 9.4, 10.3, 4.5, 6.3, 9.7,
              1.2, 1.6, 7.7, 9.1, 7.3, 8.5, 2.1, 8.2, 6.1, 3.8, 10.8, 5.5, 2.1, 10.1, 7.5, 6.6, 2.7, 2.9, 0.5, 2.3, 5.0, 8.9, 4.1, 2.8,
             4.1, 4.3, 4.3, 9.6, 8.5, 6.1, 3.1, 3.7])

# %%
print(np.average(x1), np.average(y1))
# Out:
# 5.4444444444444455 5.325396825396825

# %%
print(np.average(x2), np.average(y2))
# Out:
# 5.4444444444444455 5.325396825396826

# %%
print(np.var(x1), np.var(y1))
# Out:
# 7.998024691358024 8.21554547745024

# %%
print(np.var(x2), np.var(y2))
# Out:
# 7.998024691358024 8.21554547745024

# %%
plt.scatter(x1, y1)

# %%
plt.scatter(x2, y2)

# %%
np.corrcoef(x1, y1)
# Out:
# array([[1.        , 0.95311636],
#        [0.95311636, 1.        ]])

# %%
np.corrcoef(x2, y2)
# Out:
# array([[1.        , 0.23264773],
#        [0.23264773, 1.        ]])

# %%
data1 = [[1 ,1],
         [2.2, 1.5],
         [1.5 ,2.2],
         [2.3 ,3.6],
         [5.8 ,4.7],
         [4.1 ,4.3],
         [6.7 ,7.6],
         [5.8 ,6.3],
         [4.9 ,3.7],
         [7.7 ,6.5],
         [6.5 ,7.7],
         [9.6 ,7.3],
         [9.3 ,10.3],
         [11.2, 10.4],
         [3.4 ,4.2],
         [5.4, 5.9],
         [8.4 ,8.7],
         [6.5, 6.8],
         [1.1 ,0.7],
         [2.4, 2.1],
         [3.2, 2.7],
         [4.4 ,4.5],
         [7.7, 8.4],
         [6.6, 5.9],
         [3.2, 2.7],
         [2.9 ,2.4],
         [9.8, 9.4],
         [8 ,8],
         [3 ,3],
         [2.2, 2.2],
         [9.5, 9.7],
         [1.2, 1.2,],
         [2.3, 1.6],
         [1.4, 2.7],
         [2.5, 3.1],
         [5.7, 4.1],
         [4.4 ,4.3],
         [6.5, 7.5],
         [5.6, 6.6],
         [4.7, 3.8],
         [7.8, 6.1],
         [6.9, 7.3],
         [9.7, 7.7],
         [9.6, 10.8], 
         [11.4, 10.1],
         [3.7, 4.3],
         [5.6, 5.5],
         [8.3, 8.2],
         [6.2, 6.1],
         [1.5 ,0.5],
         [2.6, 2.3],
         [3.7, 2.1],
         [4.9, 4.1],
         [7.2, 8.9],
         [6.5, 5.0],
         [3.1, 2.1],
         [2.5, 2.8],
         [9.6, 9.6],
         [8.3, 8.5],
         [3.5, 3.7],
         [2.7, 2.9],
         [9.1, 9.1],
         [8 ,8.5]]

# %%
data1 = np.array(data1)

# %%
from ripser import Rips

rips = Rips()
diagrams = rips.fit_transform(data1)
rips.plot(diagrams)
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %%
data2 = [[1 ,1],
         [2.2, 4.3],
         [1.5 ,2.2],
         [2.3 ,4.7],
         [5.8 ,7.7],
         [4.1 ,7.3],
         [6.7 ,3],
         [5.8 ,8.7],
         [4.9 ,7.6],
         [7.7 ,2.4],
         [6.5 ,8.4],
         [9.6 ,5.9],
         [9.3 ,3.7],
         [11.2, 10.4],
         [3.4 ,8],
         [5.4, 2.7],
         [8.4 ,2.2],
         [6.5, 2.1],
         [1.1 ,0.7],
         [2.4, 6.8],
         [3.2, 5.9],
         [4.4 ,1.5],
         [7.7, 3.6],
         [6.6, 2.7],
         [3.2, 6.5],
         [2.9 ,4.2],
         [9.8, 9.4],
         [8 ,10.3],
         [3 ,4.5],
         [2.2, 6.3],
         [9.5, 9.7],
         [1.2, 1.2],
         [2.3, 1.6],
         [1.4, 7.7],
         [2.5, 9.1],
         [5.7, 7.3],
         [4.4 ,8.5],
         [6.5, 2.1],
         [5.6, 8.2],
         [4.7, 6.1],
         [7.8, 3.8],
         [6.9, 10.8],
         [9.7, 5.5],
         [9.6, 2.1], 
         [11.4, 10.1],
         [3.7, 7.5],
         [5.6, 6.6],
         [8.3, 2.7],
         [6.2, 2.9],
         [1.5 ,0.5],
         [2.6, 2.3],
         [3.7, 5.0],
         [4.9, 8.9],
         [7.2, 4.1],
         [6.5, 2.8],
         [3.1, 4.1],
         [2.5, 4.3],
         [9.6, 4.3],
         [8.3, 9.6],
         [3.5, 8.5],
         [2.7, 6.1],
         [9.1, 3.1],
         [8 , 3.7]]

# %%
#ようやく成功 2/19

data2 = np.array(data2)

diagrams = ripser(data2)['dgms']
diagrams = rips.fit_transform(data2)
plot_diagrams(diagrams, show=True)

# %%
x1 = np.array([1, 2.2, 1.5, 2.3, 5.8, 4.1, 6.7, 5.8, 4.9, 7.7, 6.5, 9.6, 9.3, 11.2, 3.4, 5.4, 8.4, 6.5, 1.1, 2.4, 3.2, 4.4, 7.7, 6.6,
             3.2, 2.9, 9.8, 8, 3, 2.2, 9.5,
               1.2, 2.3, 1.4, 2.5, 5.7, 4.4, 6.5, 5.6, 4.7, 7.8, 6.9, 9.7, 9.6, 11.4, 3.7, 5.6, 8.3, 6.2, 1.5, 2.6, 3.7, 4.9, 7.2, 6.5,
             3.1, 2.5, 9.6, 8.3, 3.5, 2.7, 9.1, 8])
y1 = np.array([1, 1.5, 2.2, 3.6, 4.7, 4.3, 7.6, 6.3, 3.7, 6.5, 7.7, 7.3, 10.3, 10.4, 4.2, 5.9, 8.7, 6.8, 0.7, 2.1, 2.7, 4.5, 8.4, 5.9,
             2.7, 2.4 ,9.4, 8, 3, 2.2, 9.7,
              1.2, 1.6, 2.7, 3.1, 4.1, 4.3, 7.5, 6.6, 3.8, 6.1, 7.3, 7.7, 10.8, 10.1, 4.3, 5.5, 8.2, 6.1, 0.5, 2.3, 2.1, 4.1, 8.9, 5.0,
             2.1, 2.8 ,9.6, 8.5, 3.7, 2.9, 9.1,8.5])
z1 = np.array([1, 1.4, 2.4, 3.5, 4.3, 4.4, 7.0, 6.0, 3.3, 6.4, 7.1, 7.9, 10.1, 10.9, 4.8, 5.6, 8.6, 6.0, 0.1, 2.2, 2.4, 4.4, 8.0, 5.6,
             2.7, 2.4 ,9.4, 8, 3, 2.2, 9.7,
              1.3, 1.4, 2.5, 3.7, 4.3, 4.4, 7.6, 6.3, 3.4, 6.3, 7.5, 7.4, 10.4, 10.5, 4.2, 5.4, 8.3, 6.3, 0.7, 2.4, 2.5, 4.3, 8.6, 5.5,
             2.2, 2.3 ,9.1, 8.3, 3.2, 2.5, 9.3, 8.4])

# %%
# グラフの枠を作成
fig = plt.figure()
ax = Axes3D(fig)

# X,Y,Z軸にラベルを設定
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

# .plotで描画
ax.plot(x1,y1,z1,marker="o",linestyle='None')

# 最後に.show()を書いてグラフ表示
plt.show()

# %%
data1 = np.array([x1, y1, z1])
diagrams1 = ripser(data1)['dgms']
plot_diagrams(diagrams1, show=True)
# Out:
# C:\Users\trivial system\Anaconda3\lib\site-packages\ripser\ripser.py:253: UserWarning: The input point cloud has more columns than rows; did you mean to transpose?
#   warnings.warn(

# %%
x2 = np.array([1, 2.2, 1.5, 2.3, 5.8, 4.1, 6.7, 5.8, 4.9, 7.7, 6.5, 9.6, 9.3, 11.2, 3.4, 5.4, 8.4, 6.5, 1.1, 2.4, 3.2, 4.4, 7.7, 6.6,
             3.2, 2.9, 9.8, 8, 3, 2.2, 9.5,
              1.2, 2.3, 1.4, 2.5, 5.7, 4.4, 6.5, 5.6, 4.7, 7.8, 6.9, 9.7, 9.6, 11.4, 3.7, 5.6, 8.3, 6.2, 1.5, 2.6, 3.7, 4.9, 7.2, 6.5,
             3.1, 2.5, 9.6, 8.3, 3.5, 2.7, 9.1, 8,1, 4.3, 2.2, 4.7, 7.7, 7.3, 3, 8.7, 7.6, 2.4, 8.4, 5.9, 3.7, 10.4, 8, 2.7, 2.2, 2.1, 0.7, 6.8, 5.9, 1.5, 3.6, 2.7,
             6.5, 4.2, 9.4, 10.3, 4.5, 6.3, 9.7,
              1.2, 1.6, 7.7, 9.1, 7.3, 8.5, 2.1, 8.2, 6.1, 3.8, 10.8, 5.5, 2.1, 10.1, 7.5, 6.6, 2.7, 2.9, 0.5, 2.3, 5.0, 8.9, 4.1, 2.8,
             4.1, 4.3, 4.3, 9.6, 8.5, 6.1, 3.1, 3.7])
y2 = np.array([1, 4.3, 2.2, 4.7, 7.7, 7.3, 3, 8.7, 7.6, 2.4, 8.4, 5.9, 3.7, 10.4, 8, 2.7, 2.2, 2.1, 0.7, 6.8, 5.9, 1.5, 3.6, 2.7,
             6.5, 4.2, 9.4, 10.3, 4.5, 6.3, 9.7,
              1.2, 1.6, 7.7, 9.1, 7.3, 8.5, 2.1, 8.2, 6.1, 3.8, 10.8, 5.5, 2.1, 10.1, 7.5, 6.6, 2.7, 2.9, 0.5, 2.3, 5.0, 8.9, 4.1, 2.8,
             4.1, 4.3, 4.3, 9.6, 8.5, 6.1, 3.1, 3.7,
              1, 4.3, 2.2, 4.7, 7.7, 7.3, 3, 8.7, 7.6, 2.4, 8.4, 5.9, 3.7, 10.4, 8, 2.7, 2.2, 2.1, 0.7, 6.8, 5.9, 1.5, 3.6, 2.7,
             6.5, 4.2, 9.4, 10.3, 4.5, 6.3, 9.7,
              1.2, 1.6, 7.7, 9.1, 7.3, 8.5, 2.1, 8.2, 6.1, 3.8, 10.8, 5.5, 2.1, 10.1, 7.5, 6.6, 2.7, 2.9, 0.5, 2.3, 5.0, 8.9, 4.1, 2.8,
             4.1, 4.3, 4.3, 9.6, 8.5, 6.1, 3.1, 3.7])
z2 = np.array([1, 4.3, 2.2, 4.7, 7.7, 7.3, 3, 8.7, 7.6, 2.4, 8.4, 5.9, 3.7, 10.4, 8, 2.7, 2.2, 2.1, 0.7, 6.8, 5.9, 1.5, 3.6, 2.7,
             6.5, 4.2, 9.4, 10.3, 4.5, 6.3, 9.7,
              1.2, 1.6, 7.7, 9.1, 7.3, 8.5, 2.1, 8.2, 6.1, 3.8, 10.8, 5.5, 2.1, 10.1, 7.5, 6.6, 2.7, 2.9, 0.5, 2.3, 5.0, 8.9, 4.1, 2.8,
             4.1, 4.3, 4.3, 9.6, 8.5, 6.1, 3.1, 3.7,
                1.2, 2.3, 1.4, 2.5, 5.7, 4.4, 6.5, 5.6, 4.7, 7.8, 6.9, 9.7, 9.6, 11.4, 3.7, 5.6, 8.3, 6.2, 1.5, 2.6, 3.7, 4.9, 7.2, 6.5,
             3.1, 2.5, 9.6, 8.3, 3.5, 2.7, 9.1, 8,1, 4.3, 2.2, 4.7, 7.7, 7.3, 3, 8.7, 7.6, 2.4, 8.4, 5.9, 3.7, 10.4, 8, 2.7, 2.2, 2.1, 0.7, 6.8, 5.9, 1.5, 3.6, 2.7,
             6.5, 4.2, 9.4, 10.3, 4.5, 6.3, 9.7,])

# %%
fig = plt.figure()
ax = Axes3D(fig)

ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

ax.plot(x2,y2,z2,marker="o",linestyle='None')

plt.show()

# %%
data2 = np.array([x2, y2, z2])
diagrams2 = ripser(data2)['dgms']
plot_diagrams(diagrams2, show=True)
# Out:
# C:\Users\trivial system\Anaconda3\lib\site-packages\ripser\ripser.py:253: UserWarning: The input point cloud has more columns than rows; did you mean to transpose?
#   warnings.warn(
