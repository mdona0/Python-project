# %%
from bs4 import BeautifulSoup
from urllib.request import urlretrieve
from urllib.request import urlopen
import string
import re
from collections import Counter

# %%
def getNgrams(content, n):
    content = content.split(' ')
    output = []
    for i in range(len(content)-n+1):
        output.append(content[i:i+n])
    return output

html = urlopen('http://en.wikipedia.org/wiki/Python_(programming_language)')
bs = BeautifulSoup(html, 'html.parser')
content = bs.find('div', {'id':'mw-content-text'}).get_text()
ngrams = getNgrams(content, 2)
print(ngrams)
print('2-grams count is:' +str(len(ngrams)))
# Out:
# [['General-purpose', 'programming'], ['programming', 'language\n\n\nPythonParadigmMulti-paradigm:'], ['language\n\n\nPythonParadigmMulti-paradigm:', 'object-oriented,[1]'], ['object-oriented,[1]', 'procedural'], ['procedural', '(imperative),'], ['(imperative),', 'functional,'], ['functional,', 'structured,'], ['structured,', 'reflectiveDesigned\xa0byGuido'], ['reflectiveDesigned\xa0byGuido', 'van'], ['van', 'RossumDeveloperPython'], ['RossumDeveloperPython', 'Software'], ['Software', 'FoundationFirst\xa0appeared20\xa0February'], ['FoundationFirst\xa0appeared20\xa0February', '1991;'], ['1991;', '30'], ['30', 'years'], ['years', 'ago\xa0(1991-02-20)[2]Stable'], ['ago\xa0(1991-02-20)[2]Stable', 'release3.10.2[3]\xa0\n'], ['release3.10.2[3]\xa0\n', ''], ['', ''], ['', '/'], ['/', '14'], ['14', 'January'], ['January', '2022;'], ['2022;', '3'], ['3', 'days'], ['days', 'ago\xa0(14'], ['ago\xa0(14', 'January'], ['January', '2022)Preview'], ['2022)Preview', 'release3.11.0a4[3]\xa0\n'], ['release3.11.0a4[3]\xa0\n', ''], ['', ''], ['', '/'], ['/', '14'], ['14', 'January'], ['January', '2022;'], ['2022;', '3'], ['3', 'days'], ['days', 'ago\xa0(14'], ['ago\xa0(14', 'January'], ['January', '2022)\nTyping'], ['2022)\nTyping', 'disciplineDuck,'], ['disciplineDuck,', 'dynamic,'], ['dynamic,', 'strong'], ['strong', 'typing;[4]'], ['typing;[4]', 'gradual'], ['gradual', '(since'], ['(since', '3.5,'], ['3.5,', 'but'], ['but', 'ignored'], ['ignored', 'in'], ['in', 'CPython)[5]OSWindows,'], ['CPython)[5]OSWindows,', 'Linux/UNIX,'], ['Linux/UNIX,', 'macOS'], ['macOS', 'and'], ['and', 'more[6]LicensePython'], ['more[6]LicensePython', 'Software'], ['Software', 'Foundation'], ['Foundation', 'LicenseFilename'], ['LicenseFilename', 'extensions.py,'], ['extensions.py,', '.pyi,'], ['.pyi,', '.pyc,'], ['.pyc,', '.pyd,'], ['.pyd,', '.pyo'], ['.pyo', '(prior'], ['(prior', 'to'], ['to', '3.5),[7]'], ['3.5),[7]', '.pyw,'], ['.pyw,', '.pyz'], ['.pyz', '(since'], ['(since', '3.5)[8]Websitewww.python.orgMajor'], ['3.5)[8]Websitewww.python.orgMajor', 'implementationsCPython,'], ['implementationsCPython,', 'PyPy,'], ['PyPy,', 'Stackless'], ['Stackless', 'Python,'], ['Python,', 'MicroPython,'], ['MicroPython,', 'CircuitPython,'], ['CircuitPython,', 'IronPython,'], ['IronPython,', 'JythonDialectsCython,'], ['JythonDialectsCython,', 'RPython,'], ['RPython,', 'Starlark[9]Influenced'], ['Starlark[9]Influenced', 'byABC,[10]'], ['byABC,[10]', 'Ada,[11]'], ['Ada,[11]', 'ALGOL'], ['ALGOL', '68,[12]'], ['68,[12]', 'APL,[13]'], ['APL,[13]', 'C,[14]'], ['C,[14]', 'C++,[15]'], ['C++,[15]', 'CLU,[16]'], ['CLU,[16]', 'Dylan,[17]'], ['Dylan,[17]', 'Haskell,[18]'], ['Haskell,[18]', 'Icon,[19]'], ['Icon,[19]', 'Java,[20]'], ['Java,[20]', 'Lisp,[21]'], ['Lisp,[21]', 'Modula-3,[15]'], ['Modula-3,[15]', 'Perl,'], ['Perl,', 'Standard'], ['Standard', 'ML[13]InfluencedApache'], ['ML[13]InfluencedApache', 'Groovy,'], ['Groovy,', 'Boo,'], ['Boo,', 'Cobra,'], ['Cobra,', 'CoffeeScript,[22]'], ['CoffeeScript,[22]', 'D,'], ['D,', 'F#,'], ['F#,', 'Genie,[23]'], ['Genie,[23]', 'Go,'], ['Go,', 'JavaScript,[24][25]'], ['JavaScript,[24][25]', 'Julia,[26]'], ['Julia,[26]', 'Nim,'], ['Nim,', 'Ring,[27]'], ['Ring,[27]', 'Ruby,[28]'], ['Ruby,[28]', 'Swift[29]\n'], ['Swift[29]\n', 'Python'], ['Python', 'Programming'], ['Programming', 'at'], ['at', 'Wikibooks\n\nPython'], ['Wikibooks\n\nPython', 'is'], ['is', 'an'], ['an', 'interpreted'], ['interpreted', 'high-level'], ['high-level', 'general-purpose'], ['general-purpose', 'programming'], ['programming', 'language.'], ['language.', 'Its'], ['Its', 'design'], ['design', 'philosophy'], ['philosophy', 'emphasizes'], ['emphasizes', 'code'], ['code', 'readability'], ['readability', 'with'], ['with', 'its'], ['its', 'use'], ['use', 'of'], ['of', 'significant'], ['significant', 'indentation.'], ['indentation.', 'Its'], ['Its', 'language'], ['language', 'constructs'], ['constructs', 'as'], ['as', 'well'], ['well', 'as'], ['as', 'its'], ['its', 'object-oriented'], [ ...
# 2-grams count is:11675

# %%
def getNgrams(content, n):
    content = re.sub('\n|[[\d+\]]', ' ', content)
    content = bytes(content, 'UTF-8')
    content = content.decode('ascii', 'ignore')
    content = content.split(' ')
    content = [word for word in content if word !='']
    output = []
    for i in range(len(content)-n+1):
        output.append(content[i:i+n])
    return output

# %%
html = urlopen('http://en.wikipedia.org/wiki/Python_(programming_language)')
bs = BeautifulSoup(html, 'html.parser')
content = bs.find('div', {'id':'mw-content-text'}).get_text()
ngrams = getNgrams(content, 2)
print(ngrams)
print('2-grams count is:' +str(len(ngrams)))
# Out:
# [['General-purpose', 'programming'], ['programming', 'language'], ['language', 'PythonParadigmMulti-paradigm:'], ['PythonParadigmMulti-paradigm:', 'object-oriented,'], ['object-oriented,', 'procedural'], ['procedural', '(imperative),'], ['(imperative),', 'functional,'], ['functional,', 'structured,'], ['structured,', 'reflectiveDesignedbyGuido'], ['reflectiveDesignedbyGuido', 'van'], ['van', 'RossumDeveloperPython'], ['RossumDeveloperPython', 'Software'], ['Software', 'FoundationFirstappeared'], ['FoundationFirstappeared', 'February'], ['February', ';'], [';', 'years'], ['years', 'ago('], ['ago(', '-'], ['-', '-'], ['-', ')'], [')', 'Stable'], ['Stable', 'release'], ['release', '.'], ['.', '.'], ['.', '/'], ['/', 'January'], ['January', ';'], [';', 'days'], ['days', 'ago('], ['ago(', 'January'], ['January', ')Preview'], [')Preview', 'release'], ['release', '.'], ['.', '.'], ['.', 'a'], ['a', '/'], ['/', 'January'], ['January', ';'], [';', 'days'], ['days', 'ago('], ['ago(', 'January'], ['January', ')'], [')', 'Typing'], ['Typing', 'disciplineDuck,'], ['disciplineDuck,', 'dynamic,'], ['dynamic,', 'strong'], ['strong', 'typing;'], ['typing;', 'gradual'], ['gradual', '(since'], ['(since', '.'], ['.', ','], [',', 'but'], ['but', 'ignored'], ['ignored', 'in'], ['in', 'CPython)'], ['CPython)', 'OSWindows,'], ['OSWindows,', 'Linux/UNIX,'], ['Linux/UNIX,', 'macOS'], ['macOS', 'and'], ['and', 'more'], ['more', 'LicensePython'], ['LicensePython', 'Software'], ['Software', 'Foundation'], ['Foundation', 'LicenseFilename'], ['LicenseFilename', 'extensions.py,'], ['extensions.py,', '.pyi,'], ['.pyi,', '.pyc,'], ['.pyc,', '.pyd,'], ['.pyd,', '.pyo'], ['.pyo', '(prior'], ['(prior', 'to'], ['to', '.'], ['.', '),'], ['),', '.pyw,'], ['.pyw,', '.pyz'], ['.pyz', '(since'], ['(since', '.'], ['.', ')'], [')', 'Websitewww.python.orgMajor'], ['Websitewww.python.orgMajor', 'implementationsCPython,'], ['implementationsCPython,', 'PyPy,'], ['PyPy,', 'Stackless'], ['Stackless', 'Python,'], ['Python,', 'MicroPython,'], ['MicroPython,', 'CircuitPython,'], ['CircuitPython,', 'IronPython,'], ['IronPython,', 'JythonDialectsCython,'], ['JythonDialectsCython,', 'RPython,'], ['RPython,', 'Starlark'], ['Starlark', 'Influenced'], ['Influenced', 'byABC,'], ['byABC,', 'Ada,'], ['Ada,', 'ALGOL'], ['ALGOL', ','], [',', 'APL,'], ['APL,', 'C,'], ['C,', 'C'], ['C', ','], [',', 'CLU,'], ['CLU,', 'Dylan,'], ['Dylan,', 'Haskell,'], ['Haskell,', 'Icon,'], ['Icon,', 'Java,'], ['Java,', 'Lisp,'], ['Lisp,', 'Modula-'], ['Modula-', ','], [',', 'Perl,'], ['Perl,', 'Standard'], ['Standard', 'ML'], ['ML', 'InfluencedApache'], ['InfluencedApache', 'Groovy,'], ['Groovy,', 'Boo,'], ['Boo,', 'Cobra,'], ['Cobra,', 'CoffeeScript,'], ['CoffeeScript,', 'D,'], ['D,', 'F#,'], ['F#,', 'Genie,'], ['Genie,', 'Go,'], ['Go,', 'JavaScript,'], ['JavaScript,', 'Julia,'], ['Julia,', 'Nim,'], ['Nim,', 'Ring,'], ['Ring,', 'Ruby,'], ['Ruby,', 'Swift'], ['Swift', 'Python'], ['Python', 'Programming'], ['Programming', 'at'], ['at', 'Wikibooks'], ['Wikibooks', 'Python'], ['Python', 'is'], ['is', 'an'], ['an', 'interpreted'], ['interpreted', 'high-level'], ['high-level', 'general-purpose'], ['general-purpose', 'programming'], ['programming', 'language.'], ['language.', 'Its'], ['Its', 'design'], ['design', 'philosophy'], ['philosophy', 'emphasizes'], ['emphasizes', 'code'], ['code', 'readability'], ['readability', 'with'], ['with', 'its'], ['its', 'use'], ['use', 'of'], ['of', 'significant'], ['significant', 'indentation.'], ['indentation.', 'Its'], ['Its', 'language'], ['language', 'constructs'], ['constructs', 'as'], ['as', 'well'], ['well', 'as'], ['as', 'its'], ['its', 'object-oriented'], ['object-oriented', 'approach'], ['approach', 'aim'], ['aim', 'to'], ['to', 'help'], ['help', 'programmers'], ['programmers', 'write'], ['write', 'clear,'], ['clear,', 'logical'], ['logical', 'code'], ['code', 'for'], ['for', 'small'], ['small', 'and'], ['and', 'large-scale'], ['large-scale', 'projects.'], ['projects.', ...
# 2-grams count is:12466
# <ipython-input-8-11154737b118>:2: FutureWarning: Possible nested set at position 3
#   content = re.sub('\n|[[\d+\]]', ' ', content)

# %%
def cleanSentence(sentence):
    sentence = sentence.split(' ')
    sentence = [word.strip(string.punctuation+string.whitespace) for word in sentence]
    sentence = [word for word in sentence if len(word) > 1 or (word.lower() == 'a' or word.lower() == 'i')]
    return sentence

def cleanInput(content):
    content = re.sub('\n|[[\d+\]]', ' ', content)
    content = bytes(content, 'UTF-8')
    content = content.decode('ascii', 'ignore')
    sentences = content.split('. ')
    return [cleanSentence(sentence) for sentence in sentences]

def getNgramsFromSentence(content, n):
    output = []
    for i in range(len(content)-n+1):
        output.append(content[i:i+n])
    return output

def getNgrams(content, n):
    content = cleanInput(content)
    ngrams = []
    for sentence in content:
        ngrams.extend(getNgramsFromSentence(sentence, n))
    return(ngrams)

# %%
html = urlopen('http://en.wikipedia.org/wiki/Python_(programming_language)')
bs = BeautifulSoup(html, 'html.parser')
content = bs.find('div', {'id':'mw-content-text'}).get_text()
ngrams = getNgrams(content, 2)
print(ngrams)
print('2-grams count is:' +str(len(ngrams)))
# Out:
# [['General-purpose', 'programming'], ['programming', 'language'], ['language', 'PythonParadigmMulti-paradigm'], ['PythonParadigmMulti-paradigm', 'object-oriented'], ['object-oriented', 'procedural'], ['procedural', 'imperative'], ['imperative', 'functional'], ['functional', 'structured'], ['structured', 'reflectiveDesignedbyGuido'], ['reflectiveDesignedbyGuido', 'van'], ['van', 'RossumDeveloperPython'], ['RossumDeveloperPython', 'Software'], ['Software', 'FoundationFirstappeared'], ['FoundationFirstappeared', 'February'], ['February', 'years'], ['years', 'ago'], ['ago', 'Stable'], ['Stable', 'release'], ['January', 'days'], ['days', 'ago'], ['ago', 'January'], ['January', 'Preview'], ['Preview', 'release'], ['a', 'January'], ['January', 'days'], ['days', 'ago'], ['ago', 'January'], ['January', 'Typing'], ['Typing', 'disciplineDuck'], ['disciplineDuck', 'dynamic'], ['dynamic', 'strong'], ['strong', 'typing'], ['typing', 'gradual'], ['gradual', 'since'], ['but', 'ignored'], ['ignored', 'in'], ['in', 'CPython'], ['CPython', 'OSWindows'], ['OSWindows', 'Linux/UNIX'], ['Linux/UNIX', 'macOS'], ['macOS', 'and'], ['and', 'more'], ['more', 'LicensePython'], ['LicensePython', 'Software'], ['Software', 'Foundation'], ['Foundation', 'LicenseFilename'], ['LicenseFilename', 'extensions.py'], ['extensions.py', 'pyi'], ['pyi', 'pyc'], ['pyc', 'pyd'], ['pyd', 'pyo'], ['pyo', 'prior'], ['prior', 'to'], ['pyw', 'pyz'], ['pyz', 'since'], ['Websitewww.python.orgMajor', 'implementationsCPython'], ['implementationsCPython', 'PyPy'], ['PyPy', 'Stackless'], ['Stackless', 'Python'], ['Python', 'MicroPython'], ['MicroPython', 'CircuitPython'], ['CircuitPython', 'IronPython'], ['IronPython', 'JythonDialectsCython'], ['JythonDialectsCython', 'RPython'], ['RPython', 'Starlark'], ['Starlark', 'Influenced'], ['Influenced', 'byABC'], ['byABC', 'Ada'], ['Ada', 'ALGOL'], ['ALGOL', 'APL'], ['APL', 'CLU'], ['CLU', 'Dylan'], ['Dylan', 'Haskell'], ['Haskell', 'Icon'], ['Icon', 'Java'], ['Java', 'Lisp'], ['Lisp', 'Modula'], ['Modula', 'Perl'], ['Perl', 'Standard'], ['Standard', 'ML'], ['ML', 'InfluencedApache'], ['InfluencedApache', 'Groovy'], ['Groovy', 'Boo'], ['Boo', 'Cobra'], ['Cobra', 'CoffeeScript'], ['CoffeeScript', 'Genie'], ['Genie', 'Go'], ['Go', 'JavaScript'], ['JavaScript', 'Julia'], ['Julia', 'Nim'], ['Nim', 'Ring'], ['Ring', 'Ruby'], ['Ruby', 'Swift'], ['Swift', 'Python'], ['Python', 'Programming'], ['Programming', 'at'], ['at', 'Wikibooks'], ['Wikibooks', 'Python'], ['Python', 'is'], ['is', 'an'], ['an', 'interpreted'], ['interpreted', 'high-level'], ['high-level', 'general-purpose'], ['general-purpose', 'programming'], ['programming', 'language'], ['Its', 'design'], ['design', 'philosophy'], ['philosophy', 'emphasizes'], ['emphasizes', 'code'], ['code', 'readability'], ['readability', 'with'], ['with', 'its'], ['its', 'use'], ['use', 'of'], ['of', 'significant'], ['significant', 'indentation'], ['Its', 'language'], ['language', 'constructs'], ['constructs', 'as'], ['as', 'well'], ['well', 'as'], ['as', 'its'], ['its', 'object-oriented'], ['object-oriented', 'approach'], ['approach', 'aim'], ['aim', 'to'], ['to', 'help'], ['help', 'programmers'], ['programmers', 'write'], ['write', 'clear'], ['clear', 'logical'], ['logical', 'code'], ['code', 'for'], ['for', 'small'], ['small', 'and'], ['and', 'large-scale'], ['large-scale', 'projects'], ['Python', 'is'], ['is', 'dynamically-typed'], ['dynamically-typed', 'and'], ['and', 'garbage-collected'], ['It', 'supports'], ['supports', 'multiple'], ['multiple', 'programming'], ['programming', 'paradigms'], ['paradigms', 'including'], ['including', 'structured'], ['structured', 'particularly'], ['particularly', 'procedural'], ['procedural', 'object-oriented'], ['object-oriented', 'and'], ['and', 'functional'], ['functional', 'programming'], ['It', 'is'], ['is', 'often'], ['often', 'described'], ['described', 'as'], ['as', 'a'], ['a', 'batteries'], ['batteries', 'included'], ['included', 'language'], ['language',  ...
# 2-grams count is:9415

# %%
def cleanSentence(sentence):
    sentence = sentence.split(' ')
    sentence = [word.strip(string.punctuation+string.whitespace) for word in sentence]
    sentence = [word for word in sentence if len(word) > 1 or (word.lower() == 'a' or word.lower() == 'i')]
    return sentence

def cleanInput(content):
    content = re.sub('\n|[[\d+\]]', ' ', content)
    content = bytes(content, 'UTF-8')
    content = content.decode('ascii', 'ignore')
    sentences = content.split('. ')
    return [cleanSentence(sentence) for sentence in sentences]

def getNgramsFromSentence(content, n):
    output = []
    for i in range(len(content)-n+1):
        output.append(content[i:i+n])
    return output

def getNgrams(content, n):
    content = cleanInput(content)
    ngrams = Counter()
    for sentence in content:
        newNgrams = [' '.join(ngram) for ngram in getNgramsFromSentence(sentence, 2)]
        ngrams.update(newNgrams)
    return(ngrams)

# %%
html = urlopen('http://en.wikipedia.org/wiki/Python_(programming_language)')
bs = BeautifulSoup(html, 'html.parser')
content = bs.find('div', {'id':'mw-content-text'}).get_text()
ngrams = getNgrams(content, 2)
print(ngrams)
print('2-grams count is:' +str(len(ngrams)))
# Out:
# Counter({'from the': 220, 'the original': 211, 'original on': 209, 'Archived from': 202, 'on June': 62, 'Software Foundation': 40, 'of the': 39, 'Python Software': 37, 'of Python': 34, 'Retrieved February': 31, 'Retrieved March': 27, 'in the': 25, 'in Python': 25, 'such as': 23, 'Retrieved January': 23, 'on May': 21, 'as a': 20, 'van Rossum': 19, 'on October': 18, 'Retrieved November': 18, 'on December': 17, 'is a': 17, 'Retrieved June': 17, 'Retrieved July': 17, 'on April': 17, 'to the': 15, 'the Python': 15, 'can be': 15, 'Python Enhancement': 15, 'on March': 15, 'Retrieved April': 15, 'be used': 14, 'Retrieved May': 14, 'Enhancement Proposals': 14, 'Retrieved December': 14, 'on February': 14, 'to be': 13, 'for Python': 13, 'Retrieved September': 13, 'Python is': 12, 'standard library': 12, 'on August': 12, 'Rossum Guido': 12, 'on January': 12, 'programming language': 11, 'to Python': 11, 'of a': 11, 'used to': 11, 'other languages': 10, 'for the': 10, 'statement which': 10, 'on November': 10, 'on July': 10, 'the language': 9, 'with the': 9, 'as the': 9, 'Python for': 9, 'Guido van': 8, 'Python and': 8, 'to a': 8, 'does not': 8, 'for example': 8, 'part of': 8, 'Python has': 8, 'on the': 8, 'Retrieved August': 8, 'use of': 7, 'and a': 7, 'programming languages': 7, 'with a': 7, 'syntax and': 7, 'a Python': 7, 'written in': 7, 'the standard': 7, 'in a': 7, 'In Python': 7, 'are not': 7, 'the same': 7, 'with Python': 7, 'Programming Language': 7, 'The Python': 7, 'Retrieved October': 7, 'It is': 6, 'in and': 6, 'language that': 6, 'of its': 6, 'Python uses': 6, 'is also': 6, 'code is': 6, 'is used': 6, 'used in': 6, 'Python a': 6, 'and is': 6, 'and the': 6, 'scripting language': 6, 'Python to': 6, 'PEP Python': 6, 'Stackless Python': 5, 'on Python': 5, 'Python in': 5, 'was released': 5, 'new features': 5, 'that is': 5, 'is not': 5, 'and semantics': 5, 'better than': 5, 'languages such': 5, 'Monty Python': 5, 'it is': 5, "edit Python's": 5, 'from a': 5, 'which is': 5, 'used as': 5, 'is the': 5, 'contain mixed': 5, 'mixed types': 5, 'Python as': 5, 'a scripting': 5, 'on September': 5, 'Archived PDF': 5, 'PDF from': 5, 'Free Software': 5, 'well as': 4, 'as Python': 4, 'reference counting': 4, 'See also': 4, 'Main article': 4, 'History of': 4, 'support for': 4, 'Python code': 4, 'typing and': 4, 'is better': 4, 'to do': 4, 'and Python': 4, 'many other': 4, 'rather than': 4, 'assignment statement': 4, 'block of': 4, 'of code': 4, 'by the': 4, 'a variable': 4, 'from Python': 4, 'floor division': 4, 'operator for': 4, 'may be': 4, 'Java and': 4, 'that the': 4, 'number of': 4, 'they are': 4, 'kinds of': 4, 'quote marks': 4, 'Perl and': 4, 'use the': 4, 'is for': 4, 'used for': 4, 'can contain': 4, 'example the': 4, 'Comparison of': 4, 'latest release': 4, 'release in': 4, 'the use': 4, 'the version': 4, 'version number': 4, 'number is': 4, 'is incremented': 4, 'General Python': 4, 'Python FAQ': 4, 'Python Insider': 4, 'Python Language': 4, "Python Developer's": 4, "Developer's Guide": 4, 'archived from': 4, 'in Science': 4, 'macOS and': 3, 'design philosophy': 3, 'as well': 3, 'as its': 3, 'functional programming': 3, 'released in': 3, 'a cycle-detecting': 3, 'cycle-detecting garbage': 3, 'was a': 3, 'a major': 3, 'Python was': 3, 'one of': 3, 'most popular': 3, 'philosophy and': 3, 'to other': 3, 'Python Python': 3, 'Python community': 3, 'a large': 3, 'are supported': 3, 'edit Python': 3, 'It also': 3, 'It has': 3, 'large standard': 3, 'library and': 3, 'contrast to': 3, 'at the': 3, 'reference implementation': 3, 'Python interpreter': 3, 'language to': 3, 'to use': 3, 'This is': 3, 'in its': 3, 'have a': 3, 'that it': 3, 'uses Python': 3, 'edit Main': 3, 'Python syntax': 3, 'and it': 3, 'executes a': 3, 'a block': 3, 'code block': 3, 'statement used': 3, 'object-oriented programming': 3, 'to create': 3, 'a value': 3, 'a generator': 3, 'From Python': 3, 'similar to': 3, 'There are': 3, 'integer division': 3, 'uses the': 3, 'infix oper ...
# 2-grams count is:6450

# %%
def cleanSentence(sentence):
    sentence = sentence.split(' ')
    sentence = [word.strip(string.punctuation+string.whitespace) for word in sentence]
    sentence = [word for word in sentence if len(word) > 1 or (word.lower() == 'a' or word.lower() == 'i')]
    return sentence

def cleanInput(content):
    content = re.sub('\n', ' ', content)
    content = bytes(content, 'UTF-8')
    content = content.decode('ascii', 'ignore')
    sentences = content.split('. ')
    return [cleanSentence(sentence) for sentence in sentences]

def getNgramsFromSentence(content, n):
    output = []
    for i in range(len(content)-n+1):
        output.append(content[i:i+n])
    return output

def getNgrams(content, n):
    content = cleanInput(content)
    ngrams = Counter()
    ngrams_list = []
    for sentence in content:
        newNgrams = [' '.join(ngram) for ngram in getNgramsFromSentence(sentence, 2)]
        ngrams_list.extend(newNgrams)
        ngrams.update(newNgrams)
    return(ngrams)

content = str(urlopen('http://pythonscraping.com/files/inaugurationSpeech.txt').read(), 'utf-8')
ngrams = getNgrams(content, 2)
print(ngrams)
# Out:
# Counter({'of the': 212, 'in the': 62, 'to the': 60, 'by the': 41, 'the Constitution': 32, 'of our': 29, 'to be': 26, 'from the': 24, 'the people': 23, 'that the': 23, 'of a': 22, 'and the': 22, 'may be': 19, 'of their': 19, 'of that': 18, 'for the': 16, 'of its': 16, 'of power': 16, 'have been': 16, 'is the': 16, 'with the': 15, 'it is': 15, 'all the': 14, 'which they': 13, 'has been': 13, 'power to': 12, 'the Government': 12, 'the power': 11, 'that of': 11, 'as to': 11, 'their own': 11, 'spirit of': 
asury': 4, 'the citizens': 4, 'any of': 4, 'the respective': 4, 'to all': 4, 'citizen of': 4, 'but that': 4, 'a spirit': 4, 'from a': 3, 'which I': 3, 'with our': 3, 'called upon': 3, 'upon to': 3, 'some of': 3, 'instances of': 3, 'Chief Magistrate': 3, 'to keep': 3, 'principles and': 3, 'and opinions': 3, 'who have': 3, 'by an': 3, 'my countrymen': 3, 'mass of': 3, 'those who': 3, 'they might': 3, 'my hands': 3, 'upon which': 3, 'but to': 3, 'the duty': 3, 'produce the': 3, 'the greatest': 3, 'those which': 3, 'a ...

# %%
def isCommon(ngram):
    commonWords = ['THE', 'BE', 'AND', 'OF', 'A', 'IN', 'TO', 'HAVE', 'IT', 'I', 'THAT', 'FOR', 'YOU', 'HE', 'WITH', 'ON', 'DO', 'SAY', 'THIS', 'THEY', 'IS', 'AN', 'AT', 'BUT', 'WE', 'HIS', 'FROM', 'THAT', 'NOT', 'BY', 'SHE', 'OR', 'AS', 'WHAT', 'GO', 'THEIR', 'CAN', 'WHO', 'GET', 'IF', 'WOULD', 'HER', 'ALL', 'MY', 'MAKE', 'ABOUT', 'KNOW', 'WILL', 'AS', 'UP', 'ONE', 'TIME', 'HAS', 'BEEN', 'THERE', 'YEAR', 'SO', 'THINK', 'WHEN', 'WHICH', 'THEM', 'SOME', 'ME', 'PEOPLE', 'TAKE', 'OUT', 'INTO', 'JUST', 'SEE', 'HIM', 'YOUR', 'COME', 'COULD', 'NOW', 'THAN', 'LIKE', 'OTHER', 'HOW', 'THEN', 'ITS', 'OUR', 'TWO', 'MORE', 'THESE', 'WANT', 'WAY', 'LOOK', 'FIRST', 'ALSO', 'NEW', 'BECAUSE', 'DAY', 'MORE', 'USE', 'NO', 'MAN', 'FIND', 'HERE', 'THING', 'GIVE', 'MANY', 'WELL']
    for word in ngram:
        if word in commonWords:
            return True
    return False

def getNgramsFromSentence(content, n):
    output = []
    for i in range(len(content)-n+1):
        if not isCommon(content[i:i+n]):
            output.append(content[i:i+n])
    return output

ngrams = getNgrams(content, 3)
print(ngrams)
# Out:
# Counter({'of the': 212, 'in the': 62, 'to the': 60, 'by the': 41, 'the Constitution': 32, 'of our': 29, 'to be': 26, 'from the': 24, 'the people': 23, 'that the': 23, 'of a': 22, 'and the': 22, 'may be': 19, 'of their': 19, 'of that': 18, 'for the': 16, 'of its': 16, 'of power': 16, 'have been': 16, 'is the': 16, 'with the': 15, 'it is': 15, 'all the': 14, 'which they': 13, 'has been': 13, 'power to': 12, 'the Government': 12, 'the power': 11, 'that of': 11, 'as to': 11, 'their own': 11, 'spirit of': 11, 'the Executive': 11, 'which the': 10, 'which it': 10, 'upon the': 10, 'can be': 10, 'the United': 10, 'United States': 10, 'the same': 10, 'as the': 10, 'part of': 10, 'the character': 10, 'of liberty': 10, 'of my': 9, 'of all': 9, 'of any': 9, 'the President': 9, 'the whole': 9, 'to a': 8, 'of those': 8, 'which our': 8, 'the great': 8, 'and that': 8, 'and of': 8, 'the legislative': 8, 'It is': 8, 'the States': 8, 'would be': 8, 'in their': 8, 'character of': 8, 'there is': 8, 'the public': 8, 'should be': 8, 'to have': 7, 'on the': 7, '